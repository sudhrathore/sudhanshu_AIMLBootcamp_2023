# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhrathore/sudhanshu_AIMLBootcamp_2023/blob/main/openai_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dataset='/content/drive/MyDrive/disease symptoms prediction.csv'
import pandas as pd
df=pd.read_csv(dataset)
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import openai

openai.api_key = "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"  # Replace with your actual API key

def check_api_key():
    try:
        openai.Completion.create(
            engine="davinci",
            prompt="Hello, World!",
            max_tokens=5
        )
        print("API key is working!")
    except Exception as e:
        print("API key is not working. Error:", str(e))

check_api_key()
# Out:
# API key is working!

# %%
import pandas as pd

import numpy as np

import openai




# Set up OpenAI API credentials

openai.api_key = "Your api key"




# Define the prompt

prompt = "Generate diseases and symptoms based on this dataset:"




# Read the dataset from a CSV file

df = pd.read_csv("/content/drive/MyDrive/disease symptoms prediction.csv")  # Replace with the path to your CSV file




# Split the dataset into smaller chunks

token_limit = 4097 - len(prompt)

dataset_chunks = [chunk.to_string(index=False)[:token_limit] for chunk in np.array_split(df, len(df) // 200 + 1)]




# Generate diseases and symptoms

def generate_diseases_and_symptoms(dataset_chunks):

    results = []

    for chunk in dataset_chunks:

        response = openai.Completion.create(

            engine="text-davinci-003",

            prompt=prompt + chunk,

            max_tokens=50,

            n=5,

            stop=None,

            temperature=0.8,

            top_p=1.0

        )

        completions = response.choices

        generated_data = [completion.text.strip().split("|") for completion in completions]

        results.extend(generated_data)

    return results




# Process and present the generated results

def present_results(results):

    for result in results:

        disease = result[0]

        symptoms = result[1:]

        print("Disease:", disease)

        print("Symptoms:", symptoms)

        print()




# Example usage

generated_results = generate_diseases_and_symptoms(dataset_chunks)

present_results(generated_results)
# Out:
# Disease: redness                   swelling           pain                  fever                  chills               malaise               fatigue           weakness             muscle_pain             headache        dizziness        nausea        vomiting
# Symptoms: []
#
# Disease: fever                       headache                      chills                    nausea                   vomiting                   fatigue                  body_ache          joint_pain                  dizziness                  dry_cough        feverish        weak            feverish
# Symptoms: []
#
# Disease: fever                fatigue               chills              headache            muscle_pain          joint_pain               nausea              vomiting             appetite_loss           weight_loss       dry_cough        chest_pain       shortness_of_breath     dizziness
# Symptoms: []
#
# ...
